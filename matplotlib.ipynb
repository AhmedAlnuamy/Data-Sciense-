# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([1,2,3],[4,5,6])

# %%
plt.plot([1,2,3],[4,1,6])

# %%
myarray1=[4,5,7]

# %%
myarray2=[1,9,22]

# %%
plt.plot(myarray1,myarray2)

# %%
plt.plot(myarray1,myarray2)
plt.title("two arrays")
plt.ylabel("Ahmed")
plt.xlabel("adnan")
plt.show()

# %%
myarray3=[1,2,3,4,5,6,7]
plt.plot(myarray3)
plt.title("my array")
plt.ylabel("Ahmed")
plt.xlabel("adnan")
plt.show()

# %%
myarray4=[1,2,3,4,5,6]
myarray5 =[11,7,8,19,12,9]
plt.plot(myarray4,myarray5,'ro')
plt.title("myarray4&5")
plt.ylabel("Ahmed")
plt.xlabel("adnan")
plt.show()

# %%
myarray4=[1,2,3,4,5,6]
myarray5 =[11,7,8,19,12,9]
plt.plot(myarray4,myarray5,'-g')
plt.title("myarray4&5")
plt.ylabel("Ahmed")
plt.xlabel("adnan")
plt.show()

# %%
myarray4=[1,2,3,4,5,6]
myarray5 =[11,7,8,19,12,9]
plt.plot(myarray4,myarray5,'^k:')
plt.title("myarray4&5")
plt.ylabel("Ahmed")
plt.xlabel("adnan")
plt.show()

# %%
employees_name=['Ahmed','adnan', 'hamad','omar','muhammed']
salary_names =[1100,7000,8000,1900,10000]
plt.figure(figsize=(35,10))
plt.subplot(222)
plt.bar(employees_name,salary_names)


plt.subplot(221)
plt.plot(employees_name,salary_names)

plt.subplot(223)
plt.scatter(employees_name,salary_names)

plt.subplot(224)
plt.plot(employees_name,salary_names)
plt.title("mydata")
plt.ylabel("salary")
plt.xlabel("names")
plt.show()

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import numpy as np
np.random.seed(19680801)
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()
